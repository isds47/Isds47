# %%
import pandas as pd

# %%
data0 = pd.read_csv("chunk0_head_841.csv")
data1 = pd.read_csv("chunk01_head_done.csv")
data2 = pd.read_csv("chunk02_head-done.csv")
data3 = pd.read_csv("chunk2_head _final_finalfinal.csv")
megachunk = pd.read_csv("MegaChunk.csv")
data5 = pd.read_csv("round2Bot3.csv")

# %%
megamegachunk = megachunk.append(data0).append(data1).append(data2).append(data3).append(data5)

# %%
megamegachunk
# Out:
#                                                       0     1  \
# 0     https://ekstrabladet.dk/nyheder/politik/danskp...  1952
# 1     https://ekstrabladet.dk/nyheder/politik/danskp...   448
# 2     https://ekstrabladet.dk/flash/filmogtv/daarlig...    34
# 3     https://ekstrabladet.dk/nyheder/samfund/flemmi...   227
# 4     https://ekstrabladet.dk/nyheder/samfund/venstr...    27
# ...                                                 ...   ...
# 1764  https://ekstrabladet.dk/flash/filmogtv/her-er-...    25
# 1765  https://ekstrabladet.dk/flash/udlandkendte/kar...    33
# 1766  https://ekstrabladet.dk/sport/fodbold/udenland...   106
# 1767  https://ekstrabladet.dk/biler/har-reddet-milli...    19
# 1768  https://ekstrabladet.dk/nyheder/politik/danskp...   514
#
#                                                       2  \
# 0     Statsministeren åbner for muligt påbud om mund...
# 1      Mette F. afviser at åbne for nattelivet i august
# ...

# %%
megamegachunk = megamegachunk.drop_duplicates()

# %%
megamegachunk.columns = ['url', 'comments', 'title', 'subtitle', 'body', 'date']
megamegachunk.to_csv("data.csv", index=False)

# %%
megamegachunk = pd.read_csv('data.csv')

# %%
megamegachunk
# Out:
#                                                      url  comments  \
# 0      https://ekstrabladet.dk/nyheder/politik/danskp...      1952
# 1      https://ekstrabladet.dk/nyheder/politik/danskp...       448
# 2      https://ekstrabladet.dk/flash/filmogtv/daarlig...        34
# 3      https://ekstrabladet.dk/nyheder/samfund/flemmi...       227
# 4      https://ekstrabladet.dk/nyheder/samfund/venstr...        27
# ...                                                  ...       ...
# 24083  https://ekstrabladet.dk/flash/filmogtv/her-er-...        25
# 24084  https://ekstrabladet.dk/flash/udlandkendte/kar...        33
# 24085  https://ekstrabladet.dk/sport/fodbold/udenland...       106
# 24086  https://ekstrabladet.dk/biler/har-reddet-milli...        19
# 24087  https://ekstrabladet.dk/nyheder/politik/danskp...       514
#
#                                                    title  \
# 0      Statsministeren åbner for muligt påbud om mund...
# ...
